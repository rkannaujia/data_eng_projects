# %% [markdown]
# ## os module
#
# #### The os module in Python allows you to perform tasks such as file and directory manipulation, environment variable access,
# #### and process management.

# %%
# To get the location of the current working directory
import os 
os.getcwd()
# Out:
# 'C:\\Users\\msi\\python_practical\\data'

# %%
# Creating a Directory
os.mkdir('C:\\Users\\msi\\python_practical\\data')

# %%
# change directory
os.chdir('C:\\Users\\msi\\python_practical\\data')

# %%
# Listing out Files and Directories
os.getcwd()
# Out:
# 'C:\\Users\\msi\\python_practical\\data'

# %%
os.listdir()
# Out:
# []

# %%
os.chdir('C:\\Users\\msi\\python_practical')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\msi\\python_practical'

# %%
for i in  os.listdir():
    if i=='a.py':
        os.remove(i)

# %%
# Deleting Directory or Files using Python
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'args and kwaargs.ipynb',
#  'data',
#  'encapslation.ipynb',
#  'python 1 notebook.ipynb',
#  'python 10 - string coding.ipynb',
#  'python 11Functions.ipynb',
#  'python 12 lambda .ipynb',
#  'python 13 map, filter and redce .ipynb',
#  'python 16 inheritence.ipynb',
#  'python 17 module.ipynb',
#  'python 18.ipynb',
#  'python 2 if else notebook.ipynb',
#  'python 3 loop.ipynb',
#  'python 4 list.ipynb',
#  'python 5.ipynb',
#  'python 6.ipynb',
#  'python 7 set.ipynb',
#  'python 9 string .ipynb',
#  'python14.ipynb',
#  'python15 constrctor.ipynb',
#  'python16.ipynb',
#  'test.py',
#  'ython 8 dictionary.ipynb',
#  '__pycache__']
