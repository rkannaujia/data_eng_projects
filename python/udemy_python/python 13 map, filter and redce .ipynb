# %% [markdown]
# # map(), filter(), and reduce() in Python Explained 🚀
#
# #### Python provides three powerful functional programming tools:
# #### ✅ map() → Applies a function to all elements in an iterable.
# #### ✅ filter() → Filters elements based on a condition.
# #### ✅ reduce() → Reduces a sequence to a single value.

# %% [markdown]
# ## 1️⃣ map() - Apply a Function to All Elements
#
# #### 📌 Use Case: When you need to modify all elements in a list (e.g., convert to uppercase, square numbers).

# %%
# map(function , list)

# %%
# Example: Squaring All Numbers
l=[1,3,4,5,6,7]
def sqr(n):
    return n**2
    

# map(sqr,l)

# %%
# Example: Convert a List of Strings to Uppercase

# %% [markdown]
# ## 2️⃣ filter() - Select Elements Based on a Condition
# #### 📌 Use Case: When you need to remove unwanted values (e.g., filter even numbers, find words with a specific length).

# %%
# Example: Filter Words with More Than 3 Letters

# %%
words = ["hi", "hello", "bye", "world"]

# %%
map - l = [,1

# %%
filter -

# %%
l=[True, False]

list(map(lambda n:n==True,l))
# Out:
# [True, False]

# %%
list(filter(lambda n:n==True,l))
# Out:
# [True]

# %% [markdown]
# ## 3️⃣ reduce() - Reduce a Sequence to a Single Value
#
# #### 📌 Use Case: When you need to aggregate values (e.g., sum, product, find the maximum).
#
# #### 👉 reduce() is part of functools and must be imported before use.

# %%
# Example: Sum of All Numbers

# %%
# Example: multiply of All Numbers

# %%
l = [1,3,4,5,6]
