# %% [markdown]
# ## 1.  PRINT()

# %%
print("hello world")
# Out:
# hello world

# %%
print("manish")
# Out:
# manish

# %% [markdown]
# ## 2. DATA TYPES AND VARIABLES
# #### Python provides a variety of data types to handle different kinds of data

# %%
#HOW TO CREATE VARIABLES AND CHECK THE DATA TYPE OF VARIABLE 

name = 'manish'
print(name)
# Out:
# manish

# %%
a=10 
b=40
c=60
print(b,a)
# Out:
# 40 10

# %%
#STATIC TYPING VS DYNAMIC TYPING 
a = 10 
type(a)
# Out:
# int

# %%
# c 
int a =10  - static typing 

#python 
b =10  -- dynamic typing

# %%
# PYTHON SUPPORT MULTIPLE DATA TYPES WHICH CAN HOLD VALUES IN VARIABLE LIKE STR, INT, FLOAT , COMPLEX , LIST , TUPLE ETC.

#string 
a='hello world'
type(a)
# Out:
# str

# %%
#int 
b=10
type(b)
# Out:
# int

# %%
#float
a=10.5
type(a)
# Out:
# float

# %%
#complex
a=2+5j
type(a)
# Out:
# complex

# %%
#list 
a=[1,3,4,5,6]
type(a)
# Out:
# list

# %%
#tuple
a=(1,3,4,5)
type(a)
# Out:
# tuple

# %%
#set 
a={1,3,4,5,6}
type(a)
# Out:
# set

# %%
#dict
a={'a':[1,3,4],'b':[3,4,5]}
type(a)
# Out:
# dict

# %%
#none
a=None
type(a)
# Out:
# NoneType

# %% [markdown]
# ## 3. input()  -- take user input dynamically
#
# #### The input() function in Python is used to take user input from the console. It reads a line of text entered by the user and returns it as a string.
#
# #### The input() function is an essential tool for creating interactive Python programs and collecting data from users.

# %%
email = input("enter your email address")
print(email)
# Out:
# enter your email address def@gmail.com
# def@gmail.com

# %%
email = input("enter your email address")
password= input("enter your password ")
# Out:
# enter your email address abc@gmail
# enter your password  12345

# %%
num = input("enter any number")
print(type(num))
# Out:
# enter any number 20
# <class 'str'>

# %% [markdown]
# ## 4. type casting

# %%
a=20
type(a)
# Out:
# int

# %%
a= int('20')
type(a)
# Out:
# int

# %%
b=20.2
int(b)
# Out:
# 20

# %%
a=10
float(a)
# Out:
# 10.0

# %% [markdown]
# ## 5. operators
# ### In Python, operators are special symbols or keywords that perform operations on variables and values.
#
# ### 1. Arithmetic Operators
#
# #### +	Addition	5 + 3	8
# #### -	Subtraction	5 - 3	2
# #### *	Multiplication	5 * 3	15
# #### /	Division	5 / 3	1.6667
# #### //	Floor Division	5 // 3	1
# #### %	Modulus (Remainder)	5 % 3	2
# #### **	Exponentiation	5 ** 3	125

# %%
5/3
# Out:
# 1.6666666666666667

# %%
5//3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
5**3
# Out:
# 125

# %% [markdown]
# ### 2. Comparison (Relational) Operator
# #### Compare two values and return a Boolean (True or False).
#
# #### ==	Equal to	5 == 3	False
# #### !=	Not equal to	5 != 3	True
# #### >	Greater than	5 > 3	True
# #### <	Less than	5 < 3	False
# #### >=	Greater than or equal to	5 >= 3	True
# #### %	Modulus (Remainder)	5 % 3	2
# #### <=	Less than or equal to	5 <= 3	False

# %%
5==3
# Out:
# False

# %%
5!=3
# Out:
# True

# %%
5>3
# Out:
# True

# %%
5<3
# Out:
# False

# %% [markdown]
# ### 3. Logical Operators
#
# Combine conditional statements and return Boolean values.
#
# Operator	Description	Example	Output
#
# and	Logical AND	True and False	False
#
# or	Logical OR	True or False	True
#
# not	Logical NOT	not True	False

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %% [markdown]
# #### 4. Assignment Operators
# Assign or update the value of a variable.
#
# Operator	Description	Example	Equivalent To
#
# #### =	Assign	x = 5	x = 5
#
# #### +=	Add and assign	x += 3	x = x + 3
#
# #### -=	Subtract and assign	x -= 3	x = x - 3
#
# #### *=	Multiply and assign	x *= 3	x = x * 3
#
# #### /=	Divide and assign	x /= 3	x = x / 3

# %%
x=5
x=x+3
x
# Out:
# 8

# %%
x=5
x+=3
x
# Out:
# 8

# %%
x=x-3
x-=3

# %%
x=x*3
x*=3

# %% [markdown]
# ## 5. Membership Operators
# Test for membership in a sequence.
# Operator	Description	Example	Output
#
# ### in	Checks if a value exists	'a' in 'apple'	True
#
# ### not in	Checks if a value does not exist	'x' not in 'apple'	True

# %%
'a'  not in 'apple'
# Out:
# False

# %%
in
