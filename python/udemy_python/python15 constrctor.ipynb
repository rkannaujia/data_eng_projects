# %% [markdown]
# # OBJECT ORIENTED PROGRAMMING

# %% [markdown]
# ## Constructor
#
# #### it is a special method within a class that gets atomtically called when an object is created
#
# #### it is used to intialize the attribte of an object

# %%
class demo:
    pass 

car= demo()
car1=demo()

# %%
# method -- fnction 

class demo:

    def val(self):
        print(10)

demo1=demo()
demo1.val()
# Out:
# 10

# %%
# method -- fnction 

class demo:
    a=10
    def val_show(self):
        print(self.a)

    def val_show1(self):
        print('hello')

demo1 = demo()
demo1.val_show()
demo1.val_show1()
# Out:
# 10
# hello

# %%
# constrctor 

class demo:
    def __init__(self):
        print("hello world")

    def val_show(self):
        print(10)



d1=demo()
d1.val_show()
# Out:
# hello world
# 10

# %%
class demo:
    def __init__(self,a,b):
        self.a=a
        self.b=b
        print(self.a,self.b)

    def val_show(self):
        print(self.a)

d1=demo(10,30)
d1.val_show()
# Out:
# 10 30
# 10
